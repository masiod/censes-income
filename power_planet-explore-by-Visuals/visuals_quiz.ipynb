# %% [markdown]
# # Exploring Data with Visuals Quiz
# Use the space below to explore the `powerplant_data_edited.csv` dataset to answer the quiz questions below.
#   * What is the relationship between temperature and electrical output?
#   * Does the humidity variable appear to be normally distributed?
#   * Which variable appears to have the most outliers?

# %%
# import pandas
import pandas as pd
import matplotlib as plt

# %%
# load powerplant_data_edited.csv
df =pd.read_csv('./powerplant_data_edited.csv') 
df.head()
# Out:
#    temperature  exhaust_vacuum  pressure  humidity  energy_output
# 0         8.34           40.77   1010.84     90.01         480.48
# 1        23.64           58.49   1011.40     74.20         445.75
# 2        29.74           56.90   1007.15     41.91         438.76
# 3        19.07           49.69   1007.22     76.79         453.09
# 4        11.80           40.66   1017.13     97.20         464.43

# %%
#more info about datatype 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9568 entries, 0 to 9567
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   temperature     9568 non-null   float64
#  1   exhaust_vacuum  9568 non-null   float64
#  2   pressure        9568 non-null   float64
#  3   humidity        9568 non-null   float64
#  4   energy_output   9568 non-null   float64
# dtypes: float64(5)
# memory usage: 373.9 KB

# %%
# plot relationship between temperature and electrical output using a scatter plot
df.plot(kind='scatter',x='energy_output',y='temperature');

# %% [markdown]
# # its negative colleration betweeen temperature and electrical

# %%
# plot distribution of humidity using a histogram
df['humidity'].hist(figsize=(16,8),bins=100);

# %%
# plot box plots for temperature
df['temperature'].plot(kind='box',title='plot of temp');

# %%
# plot box plots for exhaust_vacuum
df['exhaust_vacuum'].plot(kind='box',title='plot of exhaust_vacuum');

# %%
# plot box plots for pressure
df['pressure'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
# plot box plots for humidity
df['humidity'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
# plot box plots for energy_output
df['energy_output'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
# plot box plots for df
df.boxplot()
# Out:
# <AxesSubplot:>

# %%
# plot box_frame for df
pd.plotting.boxplot_frame(df,figsize=(16,10))
# Out:
# <AxesSubplot:>

# %%
# plot scatter_matrix plots for df
pd.plotting.scatter_matrix(df,figsize=(16,10))
# Out:
# array([[<AxesSubplot:xlabel='temperature', ylabel='temperature'>,
#         <AxesSubplot:xlabel='exhaust_vacuum', ylabel='temperature'>,
#         <AxesSubplot:xlabel='pressure', ylabel='temperature'>,
#         <AxesSubplot:xlabel='humidity', ylabel='temperature'>,
#         <AxesSubplot:xlabel='energy_output', ylabel='temperature'>],
#        [<AxesSubplot:xlabel='temperature', ylabel='exhaust_vacuum'>,
#         <AxesSubplot:xlabel='exhaust_vacuum', ylabel='exhaust_vacuum'>,
#         <AxesSubplot:xlabel='pressure', ylabel='exhaust_vacuum'>,
#         <AxesSubplot:xlabel='humidity', ylabel='exhaust_vacuum'>,
#         <AxesSubplot:xlabel='energy_output', ylabel='exhaust_vacuum'>],
#        [<AxesSubplot:xlabel='temperature', ylabel='pressure'>,
#         <AxesSubplot:xlabel='exhaust_vacuum', ylabel='pressure'>,
#         <AxesSubplot:xlabel='pressure', ylabel='pressure'>,
#         <AxesSubplot:xlabel='humidity', ylabel='pressure'>,
#         <AxesSubplot:xlabel='energy_output', ylabel='pressure'>],
#        [<AxesSubplot:xlabel='temperature', ylabel='humidity'>,
#         <AxesSubplot:xlabel='exhaust_vacuum', ylabel='humidity'>,
#         <AxesSubplot:xlabel='pressure', ylabel='humidity'>,
#         <AxesSubplot:xlabel='humidity', ylabel='humidity'>,
#         <AxesSubplot:xlabel='energy_output', ylabel='humidity'>],
#        [<AxesSubplot:xlabel='temperature', ylabel='energy_output'>,
#         <AxesSubplot:xlabel='exhaust_vacuum', ylabel='energy_output'>,
#         <AxesSubplot:xlabel='pressure', ylabel='energy_output'>,
#         <AxesSubplot:xlabel='humidity', ylabel='energy_output'>,
#         <AxesSubplot:xlabel='energy_output', ylabel='energy_output'>]],
#       dtype=object)
